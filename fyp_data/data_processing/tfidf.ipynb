# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pymongo
import pandas as pd

# %%
def get_all_preprocessed_content():
    my_client: pymongo.MongoClient = pymongo.MongoClient("mongodb://localhost:27017/")
    my_db: pymongo.database.Database = my_client["final-year-project"]
    content: pymongo.database.Collection = my_db["preprocessed_content"]
    try:
        result = content.find()
        return list(result)
    except Exception as e:
        print(f"An error occurred: {e}")
        return []
    
def update_preprocessed_content_table(preprocessed_content: dict):
    my_client: pymongo.MongoClient = pymongo.MongoClient("mongodb://localhost:27017/")
    my_db: pymongo.database.Database = my_client["final-year-project"]
    preprocessed_content_collection: pymongo.database.Collection = my_db["preprocessed_content"]
    try:
        # Define the filter and update operation
        filter_criteria = {"_id": preprocessed_content["_id"]}
        update_operation = {"$set": preprocessed_content}
        
        print("Going to update")
        result = preprocessed_content_collection.update_one(filter_criteria, update_operation)
        
        if result.matched_count > 0:
            print(f"Updated document with ID: {preprocessed_content['_id']}")
        else:
            print("No matching document found for update.")
        
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
preprocessed_content_data = get_all_preprocessed_content()
df = pd.DataFrame(preprocessed_content_data)
preprocessed_text_list = df["preprocessed_text"].to_list()
filtered_tokenized_texts = [' '.join(doc) for doc in preprocessed_text_list]

# %%
len(filtered_tokenized_texts)
# Out:
# 11751

# %%
# Apply TF-IDF
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(filtered_tokenized_texts)

# Get terms and their TF-IDF scores
feature_names = tfidf_vectorizer.get_feature_names_out()
dense = tfidf_matrix.todense()

# Example: Top terms for a specific document
doc_index = 10000  # Change this to analyze other documents
doc_tfidf = dense[doc_index].tolist()[0]
term_scores = [(feature_names[i], score) for i, score in enumerate(doc_tfidf) if score > 0]
sorted_terms = sorted(term_scores, key=lambda x: x[1], reverse=True)

print(f"Top terms for Document {doc_index}:")
for term, score in sorted_terms[:10]:
    print(f"{term}: {score}")
# Out:
# Top terms for Document 10000:
# alphabet: 0.5003707744064603
# hieroglyphs: 0.2792379782045501
# rebus: 0.24237631068128374
# puzzle: 0.18224119170775874
# egyptian: 0.17310734424750893
# eye: 0.155990709020018
# language: 0.15234216327618486
# image: 0.14405365494937844
# letter: 0.1395802003853798
# sound: 0.13651591538009447

# %%
preprocessed_text_list[10000]
# Out:
# ['civilizations',
#  'invent',
#  'alphabet',
#  'adaptation',
#  'latin',
#  'alphabet',
#  'hebrew',
#  'arabic',
#  'alphabet',
#  'korean',
#  'alphabet',
#  'indian',
#  'alphabets',
#  'native',
#  'indonesian',
#  'alphabets',
#  'alphabet',
#  'alphabet',
#  'ask',
#  'civilizations',
#  'invent',
#  'write',
#  'systems',
#  'different',
#  'question',
#  'answer',
#  'short',
#  'ancient',
#  'mesopotamians',
#  'egyptians',
#  'chinese',
#  'mayans',
#  'ones',
#  'know',
#  'invent',
#  'write',
#  'systems',
#  'alphabets',
#  'advance',
#  'mostlyphonetic',
#  'picture',
#  'write',
#  'rebus',
#  'write',
#  'fancy',
#  'example',
#  'use',
#  'explain',
#  'rebus',
#  'principle',
#  'work',
#  'need',
#  'hieroglyphs',
#  'language',
#  'alphabet',
#  'language',
#  'hieroglyphs',
#  'write',
#  'write',
#  'language',
#  'call',
#  'egyptian',
#  'speak',
#  'egyptian',
#  'speak',
#  'hieroglyphs',
#  'image',
#  'word',
#  'puzzle',
#  'call',
#  'rebus',
#  'picture',
#  'stand',
#  'word',
#  'sentence',
#  'particular',
#  'rebus',
#  'eye',
#  'sink',
#  'tear',
#  'eye',
#  'ham',
#  'solve',
#  'puzzle',
#  'read',
#  'previous',
#  'paragraph',
#  'congratulations',
#  'translate',
#  'english',
#  'hieroglyphs',
#  'problem',
#  'puzzle',
#  'rely',
#  'know',
#  'speak',
#  'english',
#  'let',
#  'french',
#  'rebus',
#  'try',
#  'solve',
#  'english',
#  'translate',
#  'n',
#  'bucket',
#  'moo',
#  'bench',
#  'try',
#  'sense',
#  'puzzle',
#  'rely',
#  'french',
#  'english',
#  'solve',
#  'french',
#  'nhoux',
#  'seau',
#  'meuh',
#  'banc',
#  'do',
#  'nez',
#  'mean',
#  'nous',
#  'sommes',
#  'abandonnés',
#  'abandon',
#  'translate',
#  'puzzle',
#  'know',
#  'french',
#  'english',
#  'demonstrate',
#  'result',
#  'nonsense',
#  'egyptian',
#  'oversimplify',
#  'things',
#  'write',
#  'sort',
#  'puzzle',
#  'write',
#  'picture',
#  'picture',
#  'stand',
#  'things',
#  'look',
#  'english',
#  'rebus',
#  'eye',
#  'stand',
#  'suppose',
#  'actual',
#  'representation',
#  'eye',
#  'hieroglyphs',
#  'follow',
#  'basic',
#  'idea',
#  'translate',
#  'french',
#  'puzzle',
#  'know',
#  'french',
#  'translate',
#  'egyptian',
#  'hieroglyphs',
#  'know',
#  'egyptian',
#  'hieroglyphs',
#  'contrary',
#  'popular',
#  'belief',
#  'pictographic',
#  'script',
#  'mayan',
#  'early',
#  'chinese',
#  'mesopotamian',
#  'cuneiform',
#  'work',
#  'manner',
#  'word',
#  'stand',
#  'mean',
#  'represent',
#  'sound',
#  'picture',
#  'character',
#  'eye',
#  'represent',
#  'eye',
#  'pronoun',
#  'problem',
#  'need',
#  'different',
#  'symbols',
#  'represent',
#  'syllable',
#  'systems',
#  'hundreds',
#  'thousands',
#  'character',
#  'habit',
#  'gain',
#  'egyptian',
#  'start',
#  'hieroglyphs',
#  'thousand',
#  'die',
#  'sad',
#  'little',
#  'units',
#  'school',
#  'ancient',
#  'egypt',
#  'come',
#  'disgust',
#  'inaccurate',
#  'word',
#  'incorrect',
#  'glimmer',
#  'truth',
#  'egyptians',
#  'degree',
#  'alphabet',
#  'write',
#  'character',
#  'represent',
#  'word',
#  'syllable',
#  'stand',
#  'single',
#  'sound',
#  'save',
#  'foreign',
#  'name',
#  'protoalphabet',
#  'hide',
#  'larger',
#  'pictophonetic',
#  'mention',
#  'difficult',
#  'pictophonetic',
#  'hieroglyphs',
#  'learn',
#  'convolute',
#  'inevitable',
#  'poor',
#  'group',
#  'scribe',
#  'live',
#  'sinai',
#  'peninsula',
#  'sinai',
#  'peninsula',
#  'link',
#  'africa',
#  'asia',
#  'home',
#  'important',
#  'group',
#  'frustrate',
#  'scribe',
#  'thousands',
#  'character',
#  'inconsistent',
#  'confuse',
#  'pattern',
#  'years',
#  'years',
#  'need',
#  'learn',
#  'hieroglyphs',
#  'scribe',
#  'egyptian',
#  'semites',
#  'relate',
#  'phoenicians',
#  'jews',
#  'arabs',
#  'egyptian',
#  'neighbour',
#  'look',
#  'negative',
#  'foreigners',
#  'scribe',
#  'language',
#  'suit',
#  'hieroglyphs',
#  'egyptian',
#  'language',
#  'create',
#  'declare',
#  'design',
#  'semitic',
#  'languages',
#  'thousand',
#  'time',
#  'hieroglyphs',
#  'simpler',
#  'easy',
#  'master',
#  'week',
#  'nay',
#  'day',
#  'language',
#  'write',
#  'create',
#  'scratch',
#  'know',
#  'write',
#  'egyptian',
#  'try',
#  'create',
#  'write',
#  'lot',
#  'alphabets',
#  'scribe',
#  'problem',
#  'bury',
#  'hieroglyphs',
#  'stand',
#  'syllable',
#  'word',
#  'character',
#  'represent',
#  'single',
#  'sound',
#  'let',
#  'pull',
#  'modify',
#  'language',
#  'word',
#  'sound',
#  'flesh',
#  'edge',
#  'letter',
#  'character',
#  'assign',
#  'character',
#  'crude',
#  'draw',
#  'word',
#  'start',
#  'sound',
#  'instance',
#  'k',
#  'sound',
#  'represent',
#  'draw',
#  'open',
#  'hand',
#  'kap',
#  'language',
#  'need',
#  'remember',
#  'word',
#  'associate',
#  'letter',
#  'remember',
#  'shape',
#  'sound',
#  'genius',
#  'mnemonic',
#  'ask',
#  'scribe',
#  'new',
#  'write',
#  'need',
#  'think',
#  'moment',
#  'brilliant',
#  'emerge',
#  'oxhouse',
#  'kind',
#  'use',
#  'letter',
#  'ancestor',
#  'modern',
#  'letter',
#  'name',
#  'language',
#  'word',
#  'ox',
#  'alp',
#  'alep',
#  'letter',
#  'b',
#  'name',
#  'house',
#  'bet',
#  'letter',
#  'alpbet',
#  'oxhouse',
#  'greatgreatgrandmother',
#  'letter',
#  'read',
#  'protosinatic',
#  'image',
#  'omniglot',
#  'alphabet',
#  'alphabetical',
#  'use',
#  'today',
#  'come',
#  'invent',
#  'middle',
#  'desert',
#  'fedup',
#  'scribe',
#  'alphabet',
#  'steal',
#  'ethiopians',
#  'south',
#  'phoenicians',
#  'north',
#  'send',
#  'greeks',
#  'indians',
#  'revolutionize',
#  'phoenician',
#  'alphabet',
#  'image',
#  'wikipedia',
#  'greeks',
#  'add',
#  'proper',
#  'vowels',
#  'change',
#  'name',
#  'little',
#  'aleph',
#  'bet',
#  'alpha',
#  'beta',
#  'ship',
#  'slavs',
#  'turn',
#  'cyrillic',
#  'alphabet',
#  'etruscans',
#  'lend',
#  'romans',
#  'norse',
#  'norse',
#  'turn',
#  'run',
#  'romans',
#  'turn',
#  'latin',
#  'early',
#  'greek',
#  'alphabet',
#  'image',
#  'omniglot',
#  'indians',
#  'turn',
#  'abugida',
#  'vowels',
#  'attach',
#  'consonant',
#  'character',
#  'character',
#  'result',
#  'brahmi',
#  'alphabet',
#  'history',
#  'native',
#  'script',
#  'south',
#  'southeast',
#  'asia',
#  'chinese',
#  'come',
#  'brahmi',
#  'include',
#  'korean',
#  'hangul',
#  'read',
#  'brahmi',
#  'basic',
#  'character',
#  'image',
#  'native',
#  'middle',
#  'east',
#  'develop',
#  'hebrew',
#  'arabic',
#  'alphabets',
#  'today',
#  'alien',
#  'slow',
#  'evolution',
#  'chart',
#  'image',
#  'wikipedia',
#  'answer',
#  'question',
#  'alphabet',
#  'direct',
#  'parent',
#  'alphabet',
#  'fun',
#  'little',
#  'bits',
#  'history',
#  'action',
#  'tiny',
#  'insignificant',
#  'turn',
#  'greater',
#  'meaningful',
#  'expect',
#  'answer',
#  'history',
#  'alphabet',
#  'learn',
#  'thank',
#  'ask',
#  'footnote',
#  'oscar',
#  'tays',
#  'answer',
#  'hieroglyphs',
#  'pictorial',
#  'language',
#  'translate',
#  'know',
#  'language',
#  'speak',
#  'write',
#  'oscar',
#  'tays',
#  'answer',
#  'alphabet',
#  'order',
#  'come',
#  'order',
#  'alphabet',
#  'exactly    latin alphabet',
#  'hebrew alphabet',
#  'arabic alphabet',
#  'korean alphabet',
#  'native indonesian alphabets',
#  'literally  alphabet',
#  'writing systems',
#  'different question',
#  'short  ancient mesopotamians',
#  'writing systems',
#  'advanced mostlyphonetic picture writing',
#  'rebus writing',
#  'rebus principle',
#  '“ alphabet',
#  'language hieroglyphs',
#  'word puzzle',
#  'particular rebus',
#  'eye sink',
#  'eye ham',
#  'previous paragraph',
#  'english hieroglyphs',
#  'french rebus',
#  'n’holly bucket moo',
#  'nhoux seau',
#  'nonsense\negyptian',
#  'english rebus',
#  'actual representation',
#  'eye hieroglyphs',
#  'basic idea',
#  'french puzzle',
#  'egyptian hieroglyphs',
#  'egyptian hieroglyphs',
#  'popular belief',
#  'wholly pictographic script\nmayan early chinese',
#  'mesopotamian cuneiform',
#  'character eye',
#  'literally “eye',
#  'different symbols',
#  'maybe seven  hieroglyphs',
#  'sad little units',
#  'ancient egypt',
#  'single sound',
#  'foreign names',
#  'larger pictophonetic',
#  'poor group',
#  'sinai peninsula',
#  'sinai peninsula link',
#  'unexpectedly important group',
#  'frustrated scribes\nthousands',
#  'inconsistent  confusing patterns years',
#  'egyptian neighbours',
#  'generically negative foreigners',
#  '’ language',
#  'egyptian language',
#  'semitic languages',
#  'week  nay',
#  'writing  egyptian',
#  'single sound',
#  'language’s words',
#  'crude drawing',
#  '“k” sound',
#  'open hand',
#  'genius mnemonic',
#  'new writing',
#  'oxhouse\n“oxhouse',
#  'modern letter',
#  'language’s word',
#  'letter “b',
#  'alphabet protosinatic image',
#  'truly alphabetical',
#  'phoenician alphabet image',
#  'proper vowels',
#  'little ’aleph',
#  'cyrillic alphabet',
#  'latin alphabet',
#  'early greek alphabet image',
#  'omniglot\n indians',
#  'consonant characters',
#  'brahmi alphabet',
#  'native script',
#  'south  southeast asia',
#  'korean hangul',
#  'brahmi’s basic characters image',
#  'alphabet’s native middle east',
#  'hebrew  arabic alphabets',
#  'slow evolution',
#  'direct parent',
#  'fun little bits',
#  'footnotes\n oscar',
#  'tays answer',
#  'pictorial language']

# %%
import spacy

# Load SpaCy model
nlp = spacy.load('en_core_web_sm')

def lemmatize_with_plural_check(text):
    doc = nlp(text)
    lemmatized_tokens = []

    for token in doc:
        # Check if the token is a plural noun
        if token.pos_ == 'NOUN' and token.tag_ in ('NNS', 'NNPS'):
            lemmatized_tokens.append(token.lemma_)  # Use SpaCy's built-in lemma for nouns
        else:
            lemmatized_tokens.append(token.lemma_)  # Use lemma for all other tokens

    return lemmatized_tokens



nlp("lemmatized words")[0].lemma_
# Out:
# 'lemmatize'

# %%
"asd as".split()
# Out:
# ['asd', 'as']
